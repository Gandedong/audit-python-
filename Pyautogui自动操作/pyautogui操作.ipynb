# %%
import pyautogui
pyautogui.displayMousePosition()
# Out:
# Press Ctrl-C to quit.
# ...

# %%
import pyautogui
X,Y = pyautogui.position() # 鼠标停當前位置
print(X,Y)
print(X,Y)
print(X,Y)
# Out:
# 375 201
# 375 201
# 375 201

# %% [markdown]
# 函数名称	功能	主要参数
# pyautogui.position()	鼠标当前位置值
# pyautogui.moveTo(255,100,duration=0.25)	鼠标移动到255.100位置	duration为移动时间
# pyautogui.dragTo(300,400,2,button='left')	按住鼠标左键，用2秒钟把鼠标拖拽到(300,400)位置	button为按住鼠标
# pyautogui.click(10,20,2,button='left')	用2秒钟把鼠标移到(10,20)位置，用左键点一下
# pyautogui.doubleClick(10.20)	鼠标移到(10,20)位置，用左键点两下	默认为左键
# pyautogui.scroll(10) 	向上滚动10格	10表示滚动的格数
# pyautogui.scroll(-10)	向下滚动10格	负数表示向下滚动
# pyautogui.scroll(10,x=100,y=100)	移动到(100,100)位置再向上滚动10格
# pyautogui.typewrite('Hello world!')	键盘输入文字
# pyautogui.press('enter') 	按下回车
# pyautogui.press(['left','left','left'])	按下左方向键三次
# pyautogui.keyDown('shift') 	按住shift键
# pyautogui.keyUp('shift')	松开`shift`键
# pyautogui.hotkey('ctrl','v') 	组合按键（Ctrl+V），贴上剪贴板的文字
# pyautogui.screenshot(r'C:\shot.png')	全屏截图，并保存图片和设置图片名称shot.png	图片位置和名称
# pyautogui.screenshot(r'C:\shot.png',region=(100,300,400))	指定范围截图	region为截图的长宽高
# pyautogui.locateOnScreen()	获得档案图片在现在的屏幕上面的坐标	截图没找到返回None
# pyautogui.locateAllOnScreen(r'C:\shot.png')	匹配屏幕所有与目标图片shot的对象
# ![image.png](attachment:image.png)

# %%
pyautogui.size()#屏幕像素是多少
# Out:
# Size(width=1366, height=768)

# %%
import pyautogui
#花2秒时间移动到指定位置www.baidu.com

pyautogui.moveTo(242,114,1)
#左键点击一下
pyautogui.click()
#键盘输入文字
pyautogui.typewrite('www.baidu.com')
#按下回车
pyautogui.press('enter')

# %%
#导入xlwings模块  
import xlwings as xw  
#新建工作簿，这里默认为新建了一个App，即打开Excel程序，并新建一个工作簿   
xw.Book("pyautogui函数明细.xlsx")   
sht=xw.sheets['sheet3']  
import pyautogui
#花2秒时间移动到指定位置
pyautogui.moveTo(242,114,2)
#左键点击一下
pyautogui.click()
pyautogui.click()
#键盘输入文字
pyautogui.typewrite('www.baidu.com')
#按下回车
pyautogui.press('enter')
pyautogui.press('enter')
rng=sht.range('B1')  
# 将B1单元格的值改为666  
rng.value=666
