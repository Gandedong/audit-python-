# %%
import pyautogui as pag  ##先用pip3 install python3-xlib，
#再用pip3 install pyautogui进行安装
import pyperclip
import xlwings as xw
pag.PAUSE = 0.8# pyautogui.PAUSE函数在pyautogui中含义是每一步停留时间间隔，
#模块默认值是0.1秒，不过我用的财务软件反应不过来，因此延长了时间设置成了0.5秒。
pag.FAILSAFE = True
app=xw.App(visible=False,add_book=False)
app.display_alerts=False   #不显示Excel消息框
app.screen_updating=False  #关闭屏幕更新,可加快宏的执行速度
wb = xw.Book("凭证录入模块.xlsx")
sheet = wb.sheets["录入分录明细"]
info = sheet.used_range # 读取excel中的最大行
max_row =info.last_cell.row# 读取excel中的最大行

pag.click(766, 365) # 增加凭证")
pag.hotkey('Enter')##回车 
pag.hotkey('Enter')##回车 
pag.hotkey('Enter')##回车 
for x in range(2,max_row+1):
    #pyperclip.copy(str(sheet.cell(x,1).value))##复制EXCEL中的摘要
    #pag.hotkey('ctrl', 'v')##粘贴单元格
    #pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
    #pag.typewrite(str(sheet.cell(x,2).value))##输入科目代码
    #pag.hotkey('Tab')##热键Tab到科目代码栏 
    if sheet.cells(x,3).value is None: ##Xlwings中，cell后要加S
        pag.click(755, 392) # 点击保存
        pag.click(766, 365) # 增加凭证")
        pag.hotkey('Enter')##回车 
        pag.hotkey('Enter')##回车 
        pag.hotkey('Enter')##回车 
        print(f"i={x},保存赁证")
        continue
    if sheet.cells(x,3).value=="贷":
        pag.hotkey('Backspace')
        #pag.click(680, 480 + (x%2)*40) ##点击摘要
        pyperclip.copy(str(sheet.cells(x,1).value))##复制EXCEL中的摘要
        pag.hotkey('ctrl','v')##粘贴单元格
        pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        pag.typewrite(str(sheet.cells(x,2).value))##输入科目代码
        pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        pag.typewrite(str(sheet.cells(x,5).value))##输入贷方
        pag.hotkey('Enter')##回车
        pag.hotkey('Backspace')
        print(f"i={x},str(sheet.cells(x,5).value)")
    else:
        pag.hotkey('Backspace')
       # pag.click(683, 486 + (x%2)*41) ##点击摘要
        pyperclip.copy(str(sheet.cells(x,1).value))##复制EXCEL中的摘要
        pag.hotkey('ctrl','v')##粘贴单元格
        pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        pag.typewrite(str(sheet.cells(x,2).value))##输入科目代码
        pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        pag.typewrite(str(sheet.cells(x,4).value))##输入借方
        pag.hotkey('Enter')##回车
        print(f"i={x},str(sheet.cells(x,4).value)")
        ##    elif str(sheet.cell(x,3).value=="借"):
        ##pag.hotkey('Tab')###回车 ##热键Tab到科目代码栏
        ##pag.typewrite(str(sheet.cell(x,4).value))##输入贷方
        #print(f"i={x},str(sheet.cell(x,4).value)")
wb.close()
app.quit()
# Out:
# i=2,str(sheet.cells(x,4).value)
# i=3,str(sheet.cells(x,4).value)
# i=4,str(sheet.cells(x,5).value)
# i=5,保存赁证
# i=6,str(sheet.cells(x,4).value)
# i=7,str(sheet.cells(x,5).value)
# i=8,保存赁证
# i=9,str(sheet.cells(x,4).value)
# i=10,str(sheet.cells(x,5).value)
# i=11,保存赁证
# i=12,str(sheet.cells(x,4).value)
# i=13,str(sheet.cells(x,4).value)
# i=14,str(sheet.cells(x,4).value)
# i=15,str(sheet.cells(x,5).value)
# i=16,保存赁证
# i=17,str(sheet.cells(x,4).value)
# i=18,str(sheet.cells(x,5).value)
# i=19,保存赁证
# i=20,str(sheet.cells(x,4).value)
# i=21,str(sheet.cells(x,5).value)
# i=22,str(sheet.cells(x,5).value)
# i=23,保存赁证
# i=24,str(sheet.cells(x,4).value)
# i=25,str(sheet.cells(x,5).value)
# i=26,保存赁证
# i=27,str(sheet.cells(x,4).value)
# i=28,str(sheet.cells(x,5).value)
# i=29,保存赁证
# i=30,str(sheet.cells(x,4).value)
# i=31,str(sheet.cells(x,5).value)
# i=32,保存赁证
# i=33,str(sheet.cells(x,4).value)
# i=34,str(sheet.cells(x,5).value)
