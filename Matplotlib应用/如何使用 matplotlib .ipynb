# %%
##使用 matplotlib 
import matplotlib.pyplot as plt
x = [2, 3, 4, 5, 6]
y = [5, 7, 3, 9, 5]
plt.plot(x, y)
plt.show()

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y,linewidth=20);

# %%
plt.scatter(x,y,color="red",edgecolor="red",marker="+",linewidth=20);

# %%
plt.scatter(x,y,color="red",edgecolor="red",marker="p",linewidth=20);

# %%
import matplotlib.pyplot as plt##导入制图库
import pandas as pd ##导入pandas库
df01=pd.read_excel("待处理数据.xlsx")#导入Excel文件
df01
# Out:
#      交易编号  物品        销售日期    销售数量  单位售价   单位成本       总收入      总成本      总利润
# 0     696  鲩鱼  26/06/2020  1217.0   2.18  1.22   2653.06  1484.74  1168.32
# 1     666  鳜鱼  16/11/2020  1215.0   8.38  2.02  10181.70  2454.30  7727.40
# 2     265  葡萄  18/04/2020  1212.0   5.08  3.70   6156.96  4484.40  1672.56
# 3     360  葡萄  18/05/2020  1211.0   3.04  2.20   3681.44  2664.20  1017.24
# 4     661  苹果  31/08/2020  1211.0   2.48  1.00   3003.28  1211.00  1792.28
# ..    ...  ..         ...     ...    ...   ...       ...      ...      ...
# 866   652  鳕鱼  13/06/2020    10.0   5.08  0.82     50.80     8.20    42.60
# 867   625  鲟鱼  02/06/2020     9.0  12.94  7.34    116.46    66.06    50.40
# 868   726  鲮鱼  24/09/2020     8.0   3.06  0.98     24.48     7.84    16.64
# 869   129  鲮鱼  17/02/2020     5.0  12.94  6.28     64.70    31.40    33.30
# 870   660  鱿鱼  05/09/2020     2.0  13.28  3.22     26.56     6.44    20.12
#
# [871 rows x 9 columns]

# %%
figure=plt.figure()##创建制图板
#显示中文字体为简体
plt.rcParams['font.sans-serif']=['SimHei']
x=df01["物品"]##将物品列设为X轴
y=df01["总利润"]#将总利润列设为y轴
plt.bar(x,y)##制成条形图
plt.show()

# %%
plt.xlabel('产品销售类别',c="r") ##加上X轴名称,c="r"意思是颜色为红色
plt.ylabel('利润情况',c="w") ##加上Y轴名称,c="w"意思是颜色为白色
plt.title('销售利润情况',c="y") ##加上标题
plt.bar(x,y,color="c")##制成条形图，颜色为青色
plt.show()

# %%
#添加数据标签
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
x=df01["物品"]##将物品列设为X轴
y=df01["总利润"]#将总利润列设为y轴

#设置画板
fig, ax = plt.subplots(figsize = (10,5))
ax.bar(x,y,width=0.8)
##
##ax.bar_label(rects1, padding=3)
# Out:
# <BarContainer object of 871 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [u'INFO', u'CUISINE', u'TYPE_OF_PLACE', u'DRINK', u'PLACE', u'MEAL_TIME', u'DISH', u'NEIGHBOURHOOD']
y = [160, 167, 137, 18, 120, 36, 155, 130]
ind = np.arange(len(y))

fig, ax = plt.subplots()
ax.barh(ind, y)
ax.set_yticks(ind)
ax.set_yticklabels(x)

# new helper method to auto-label bars
ax.bar_label(ax.containers[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-78d16318f51d> in <module>
#      11
#      12 # new helper method to auto-label bars
# ---> 13 ax.bar_label(ax.containers[0])
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
import matplotlib
